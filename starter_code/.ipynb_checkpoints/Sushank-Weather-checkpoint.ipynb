# %% [markdown]
# # Observable Trends
# ## Trend 1:
# ### As we get closer to the equator (latitude = 0) we observed that the weather gets warmer than compared to opposite sides of positive and negative latitude values.
# ## Trend 2:
# ### Latitude values do not affect Humidity(%), Wind Speed(MPH) and Cloudiness(%).
# ## Trend 3:
# ### Creating Northern and Southern hemisphere scatter plots helped support the trend 2 analysis.

# %%
# %matplotlib notebook

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %%
# Create empty lists to hold the following values: 
citys = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
maxTemp = []
windSpeed = []

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Created for loop to go throug each city if the name is cities list is actually city or not. If it as actually city then we are getting that city data. 

for city in cities:
    try:
        query_url = f"{url}appid={weather_api_key}&units={units}&q="
        response = requests.get(query_url + city).json()
        citys.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        maxTemp.append(response["main"]["temp_max"])
        windSpeed.append(response["wind"]["speed"])
        print(f'Retrieving {city} information for city {len(citys)}')
    except KeyError:
        print(f'{city} Does Not Exist!')
# Out:
# Retrieving ribeira grande information for city 1
# Retrieving airai information for city 2
# Retrieving cockburn town information for city 3
# Retrieving san patricio information for city 4
# Retrieving port alfred information for city 5
# Retrieving tuktoyaktuk information for city 6
# Retrieving kotido information for city 7
# Retrieving kapaa information for city 8
# Retrieving aykhal information for city 9
# Retrieving hermanus information for city 10
# Retrieving rikitea information for city 11
# Retrieving khatanga information for city 12
# Retrieving aswan information for city 13
# Retrieving barrow information for city 14
# Retrieving ranong information for city 15
# Retrieving esperance information for city 16
# Retrieving jamestown information for city 17
# Retrieving ushuaia information for city 18
# Retrieving sitka information for city 19
# Retrieving lasa information for city 20
# Retrieving sidi ali information for city 21
# Retrieving meulaboh information for city 22
# Retrieving cuxhaven information for city 23
# Retrieving guiratinga information for city 24
# Retrieving sao joao da barra information for city 25
# Retrieving brownfield information for city 26
# illoqqortoormiut Does Not Exist!
# Retrieving dongsheng information for city 27
# Retrieving lebu information for city 28
# Retrieving kununurra information for city 29
# Retrieving albany information for city 30
# Retrieving arrecife information for city 31
# Retrieving bredasdorp information for city 32
# Retrieving lompoc information for city 33
# Retrieving palana information for city 34
# Retrieving sheregesh information for city 35
# Retrieving upernavik information for city 36
# Retrieving nelson bay information for city 37
# Retrieving port-cartier information for city 38
# Retrieving bluff information for city 39
# Retrieving sarangani information for city 40
# Retrieving galveston information for city 41
# Retrieving atuona information for city 42
# Retrieving bolivar information for city 43
# tumannyy Does Not Exist!
# taolanaro Does Not Exist!
# Retrieving port elizabeth information for city 44
# Retrieving college information for city 45
# amderma Does Not Exist!
# Retrieving buraydah information for city 46
# Retrieving yerbogachen information for city 47
# Retrieving nikolskoye information for city 48
# Retrieving inhambane information for city 49
# nguiu Does Not Exist!
# Retrieving coquimbo information for city 50
# Retrieving tautira information for city 51
# Retrieving colombo information for city 52
# Retrieving canutama information for city 53
# Retrieving puerto ayora information for city 54
# Retrieving punta arenas information for city 55
# Retrieving manaure information for city 56
# Retrieving dikson information for city 57
# Retrieving leningradskiy information for city 58
# Retrieving tamandare information for city 59
# Retrieving busselton information for city 60
# Retrieving sao joao batista information for city 61
# Retrieving nueve de julio information for city 62
# Retrieving fethiye information for city 63
# Retrieving port blair information for city 64
# Retrieving homer information for city 65
# Retrieving ratnagiri information for city 66
# Retrieving mataura information for city 67
# Retrieving tiksi information for city 68
# Retrieving kodiak information for city 69
# Retrieving tasiilaq information for city 70
# Retrieving kashi information for city 71
# Retrieving springbok information for city 72
# Retrieving avarua information for city 73
# Retrieving kahului information for city 74
# Retrieving samarai information for city 75
# Retrieving karratha information for city 76
# Retrieving nishihara information for city 77
# Retrieving ambilobe information for city 78
# Retrieving kudahuvadhoo information for city 79
# Retrieving novoulyanovsk information for city 80
# Retrieving guerrero negro information for city 81
# Retrieving mumford information for city 82
# Retrieving havelock information for city 83
# Retrieving auki information for city 84
# attawapiskat Does Not Exist!
# Retrieving narsaq information for city 85
# Retrieving castro information for city 86
# Retrieving qinhuangdao information for city 87
# Retrieving belyy yar information for city 88
# Retrieving kaitangata information for city 89
# Retrieving byron bay information for city 90
# Retrieving yellowknife information for city 91
# Retrieving ponta do sol information for city 92
# Retrieving thompson information for city 93
# Retrieving tiznit information for city 94
# Retrieving saint george information for city 95
# Retrieving bud information for city 96
# Retrieving la ronge information for city 97
# Retrieving alyangula information for city 98
# samusu Does Not Exist!
# Retrieving colares information for city 99
# Retrieving jamalpur information for city 100
# Retrieving turtas information for city 101
# Retrieving new norfolk information for city 102
# Retrieving sabang information for city 103
# Retrieving maceio information for city 104
# Retrieving honiara information for city 105
# Retrieving champerico information for city 106
# Retrieving longyearbyen information for city 107
# Retrieving vaini information for city 108
# Retrieving sinnamary information for city 109
# Retrieving tuatapere information for city 110
# Retrieving arraial do cabo information for city 111
# Retrieving imbituba information for city 112
# Retrieving codrington information for city 113
# nizhneyansk Does Not Exist!
# Retrieving iqaluit information for city 114
# Retrieving chuy information for city 115
# Retrieving lagoa information for city 116
# Retrieving hambantota information for city 117
# Retrieving moree information for city 118
# Retrieving hobart information for city 119
# Retrieving nouadhibou information for city 120
# Retrieving codo information for city 121
# sinkat Does Not Exist!
# Retrieving saint-augustin information for city 122
# Retrieving paamiut information for city 123
# Retrieving xanlar information for city 124
# Retrieving cabo san lucas information for city 125
# Retrieving georgetown information for city 126
# Retrieving sokoni information for city 127
# Retrieving banikoara information for city 128
# barentsburg Does Not Exist!
# Retrieving butaritari information for city 129
# Retrieving wuwei information for city 130
# Retrieving broome information for city 131
# Retrieving pimentel information for city 132
# belushya guba Does Not Exist!
# Retrieving luderitz information for city 133
# Retrieving batagay information for city 134
# Retrieving haimen information for city 135
# Retrieving torbay information for city 136
# mys shmidta Does Not Exist!
# Retrieving obihiro information for city 137
# Retrieving urumqi information for city 138
# Retrieving riyadh information for city 139
# Retrieving namibe information for city 140
# kegayli Does Not Exist!
# Retrieving namatanai information for city 141
# palabuhanratu Does Not Exist!
# Retrieving cayenne information for city 142
# Retrieving avera information for city 143
# Retrieving biltine information for city 144
# Retrieving ancud information for city 145
# Retrieving ukiah information for city 146
# Retrieving maniitsoq information for city 147
# Retrieving nosy varika information for city 148
# Retrieving sedro-woolley information for city 149
# Retrieving bengkulu information for city 150
# Retrieving yenagoa information for city 151
# Retrieving farafangana information for city 152
# Retrieving chalmette information for city 153
# Retrieving viransehir information for city 154
# Retrieving xining information for city 155
# Retrieving san quintin information for city 156
# Retrieving grenfell information for city 157
# Retrieving saint-philippe information for city 158
# Retrieving maralal information for city 159
# Retrieving krasnokamensk information for city 160
# Retrieving camacha information for city 161
# Retrieving souillac information for city 162
# Retrieving beloha information for city 163
# Retrieving oxford information for city 164
# ngukurr Does Not Exist!
# Retrieving pisco information for city 165
# Retrieving qaanaaq information for city 166
# Retrieving ulcinj information for city 167
# Retrieving ikon-khalk information for city 168
# Retrieving verkhoyansk information for city 169
# Retrieving cape town information for city 170
# Retrieving manokwari information for city 171
# Retrieving clyde river information for city 172
# Retrieving carnarvon information for city 173
# Retrieving itarare information for city 174
# Retrieving dahod information for city 175
# Retrieving itarema information for city 176
# Retrieving chardara information for city 177
# hunza Does Not Exist!
# Retrieving sorong information for city 178
# Retrieving flin flon information for city 179
# Retrieving lavrentiya information for city 180
# Retrieving hilo information for city 181
# Retrieving harper information for city 182
# Retrieving jining information for city 183
# Retrieving sao filipe information for city 184
# Retrieving virginia beach information for city 185
# Retrieving ca mau information for city 186
# Retrieving hithadhoo information for city 187
# Retrieving the pas information for city 188
# Retrieving naryan-mar information for city 189
# Retrieving tecoanapa information for city 190
# Retrieving kasempa information for city 191
# Retrieving taltal information for city 192
# umzimvubu Does Not Exist!
# Retrieving hay river information for city 193
# Retrieving savannah bight information for city 194
# Retrieving pevek information for city 195
# Retrieving mar del plata information for city 196
# Retrieving port hardy information for city 197
# Retrieving tromso information for city 198
# Retrieving yarovoye information for city 199
# Retrieving asuncion ixtaltepec information for city 200
# Retrieving bubaque information for city 201
# Retrieving saint-pierre information for city 202
# Retrieving rocha information for city 203
# Retrieving abeche information for city 204
# Retrieving encruzilhada do sul information for city 205
# Retrieving chisec information for city 206
# Retrieving bandarbeyla information for city 207
# Retrieving gobabis information for city 208
# Retrieving roma information for city 209
# Retrieving east london information for city 210
# Retrieving ilulissat information for city 211
# sentyabrskiy Does Not Exist!
# Retrieving misratah information for city 212
# Retrieving waingapu information for city 213
# Retrieving la palma information for city 214
# Retrieving bintulu information for city 215
# Retrieving salalah information for city 216
# Retrieving pangai information for city 217
# Retrieving bethel information for city 218
# Retrieving mana information for city 219
# Retrieving nogales information for city 220
# Retrieving vilyuysk information for city 221
# Retrieving sinaloa information for city 222
# Retrieving westport information for city 223
# Retrieving nuuk information for city 224
# Retrieving inuvik information for city 225
# Retrieving lujiang information for city 226
# Retrieving sola information for city 227
# Retrieving nanortalik information for city 228
# Retrieving buala information for city 229
# Retrieving huarmey information for city 230
# Retrieving teya information for city 231
# Retrieving san rafael information for city 232
# Retrieving lexington information for city 233
# Retrieving isangel information for city 234
# Retrieving deputatskiy information for city 235
# Retrieving adrar information for city 236
# Retrieving kovur information for city 237
# Retrieving constitucion information for city 238
# Retrieving rumoi information for city 239
# Retrieving norman wells information for city 240
# Retrieving cidreira information for city 241
# Retrieving dzilam gonzalez information for city 242
# Retrieving kruisfontein information for city 243
# Retrieving katsuura information for city 244
# Retrieving tazovskiy information for city 245
# haibowan Does Not Exist!
# Retrieving sept-iles information for city 246
# Retrieving wahpeton information for city 247
# Retrieving bambous virieux information for city 248
# Retrieving taoudenni information for city 249
# Retrieving chekhov information for city 250
# Retrieving kavieng information for city 251
# Retrieving panaba information for city 252
# Retrieving korba information for city 253
# Retrieving mandan information for city 254
# Retrieving whitehorse information for city 255
# Retrieving say information for city 256
# Retrieving nyurba information for city 257
# Retrieving praia da vitoria information for city 258
# Retrieving cap malheureux information for city 259
# Retrieving makakilo city information for city 260
# andarab Does Not Exist!
# Retrieving doha information for city 261
# Retrieving ketchikan information for city 262
# Retrieving vanimo information for city 263
# Retrieving kibaya information for city 264
# Retrieving victoria information for city 265
# Retrieving kortrijk information for city 266
# Retrieving boende information for city 267
# Retrieving talnakh information for city 268
# Retrieving tocopilla information for city 269
# Retrieving tawang information for city 270
# vaitupu Does Not Exist!
# Retrieving chilca information for city 271
# Retrieving smithers information for city 272
# Retrieving palagiano information for city 273
# Retrieving tvoroyri information for city 274
# Retrieving bara information for city 275
# Retrieving aksu information for city 276
# Retrieving castletown information for city 277
# Retrieving saint anthony information for city 278
# Retrieving alofi information for city 279
# Retrieving vila franca do campo information for city 280
# Retrieving hunchun information for city 281
# lolua Does Not Exist!
# Retrieving holbeach information for city 282
# Retrieving pringsewu information for city 283
# Retrieving sudak information for city 284
# Retrieving padang information for city 285
# Retrieving pekan information for city 286
# Retrieving faanui information for city 287
# warqla Does Not Exist!
# Retrieving plettenberg bay information for city 288
# Retrieving flinders information for city 289
# Retrieving gorom-gorom information for city 290
# Retrieving margherita information for city 291
# Retrieving hasaki information for city 292
# Retrieving kroonstad information for city 293
# Retrieving berdigestyakh information for city 294
# Retrieving jumla information for city 295
# Retrieving ituacu information for city 296
# Retrieving quatre cocos information for city 297
# Retrieving challapata information for city 298
# Retrieving fort nelson information for city 299
# tsihombe Does Not Exist!
# Retrieving ponta delgada information for city 300
# Retrieving japura information for city 301
# Retrieving kapoeta information for city 302
# Retrieving nome information for city 303
# Retrieving kloulklubed information for city 304
# Retrieving torres information for city 305
# Retrieving axim information for city 306
# Retrieving hofn information for city 307
# Retrieving shelburne information for city 308
# Retrieving zelenoborskiy information for city 309
# Retrieving baglan information for city 310
# Retrieving aras information for city 311
# Retrieving lorengau information for city 312
# Retrieving zhigansk information for city 313
# Retrieving corn island information for city 314
# Retrieving vereeniging information for city 315
# marcona Does Not Exist!
# Retrieving lanxi information for city 316
# Retrieving susangerd information for city 317
# Retrieving puerto quijarro information for city 318
# Retrieving mackay information for city 319
# Retrieving chipinge information for city 320
# Retrieving vung tau information for city 321
# Retrieving wanning information for city 322
# Retrieving geraldton information for city 323
# Retrieving charters towers information for city 324
# louisbourg Does Not Exist!
# Retrieving camana information for city 325
# Retrieving kozhva information for city 326
# Retrieving cheremisinovo information for city 327
# Retrieving trat information for city 328
# Retrieving faya information for city 329
# Retrieving artyom information for city 330
# Retrieving san remo information for city 331
# Retrieving la rioja information for city 332
# Retrieving novobirilyussy information for city 333
# Retrieving coihaique information for city 334
# Retrieving kozmodemyansk information for city 335
# Retrieving rorvik information for city 336
# Retrieving pierre information for city 337
# Retrieving labuhan information for city 338
# Retrieving conde information for city 339
# Retrieving rawson information for city 340
# Retrieving vardo information for city 341
# Retrieving eisiskes information for city 342
# Retrieving praia information for city 343
# Retrieving alice springs information for city 344
# Retrieving taksimo information for city 345
# Retrieving diffa information for city 346
# Retrieving alta floresta information for city 347
# Retrieving okato information for city 348
# Retrieving terney information for city 349
# Retrieving campo grande information for city 350
# Retrieving cherskiy information for city 351
# Retrieving tessalit information for city 352
# Retrieving umm kaddadah information for city 353
# Retrieving saskylakh information for city 354
# Retrieving korla information for city 355
# Retrieving brigantine information for city 356
# Retrieving half moon bay information for city 357
# Retrieving chapais information for city 358
# Retrieving kisangani information for city 359
# Retrieving semnan information for city 360
# Retrieving khasan information for city 361
# Retrieving boyolangu information for city 362
# Retrieving mogadishu information for city 363
# Retrieving sambava information for city 364
# Retrieving west fargo information for city 365
# Retrieving tual information for city 366
# Retrieving nhulunbuy information for city 367
# Retrieving fortuna information for city 368
# Retrieving kyrksaeterora information for city 369
# Retrieving hami information for city 370
# Retrieving abu zabad information for city 371
# Retrieving bilibino information for city 372
# Retrieving ulladulla information for city 373
# grand river south east Does Not Exist!
# Retrieving khovu-aksy information for city 374
# Retrieving saint-georges information for city 375
# Retrieving seoul information for city 376
# Retrieving te anau information for city 377
# Retrieving soyo information for city 378
# buariki Does Not Exist!
# Retrieving wronki information for city 379
# wulanhaote Does Not Exist!
# Retrieving poum information for city 380
# Retrieving formosa information for city 381
# Retrieving carora information for city 382
# Retrieving aukra information for city 383
# Retrieving ust-omchug information for city 384
# Retrieving nampula information for city 385
# Retrieving olinda information for city 386
# Retrieving beeville information for city 387
# Retrieving graham information for city 388
# tapaua Does Not Exist!
# Retrieving ballina information for city 389
# Retrieving katghora information for city 390
# Retrieving rawatbhata information for city 391
# Retrieving rrogozhine information for city 392
# Retrieving akdepe information for city 393
# Retrieving iskateley information for city 394
# Retrieving banjar information for city 395
# Retrieving port macquarie information for city 396
# Retrieving severo-kurilsk information for city 397
# Retrieving kedougou information for city 398
# Retrieving elko information for city 399
# Retrieving asau information for city 400
# Retrieving henties bay information for city 401
# Retrieving dudinka information for city 402
# Retrieving filingue information for city 403
# Retrieving cuiluan information for city 404
# Retrieving san cristobal information for city 405
# Retrieving gornoye loo information for city 406
# Retrieving yulara information for city 407
# Retrieving lashio information for city 408
# Retrieving bossangoa information for city 409
# Retrieving andes information for city 410
# Retrieving nerchinskiy zavod information for city 411
# Retrieving halifax information for city 412
# Retrieving rusape information for city 413
# Retrieving kamenka information for city 414
# Retrieving ruteng information for city 415
# Retrieving tripoli information for city 416
# Retrieving kalmunai information for city 417
# Retrieving neiafu information for city 418
# Retrieving bonavista information for city 419
# Retrieving rock springs information for city 420
# Retrieving raisen information for city 421
# Retrieving mandera information for city 422
# Retrieving muzhi information for city 423
# Retrieving dergachi information for city 424
# Retrieving uhlove information for city 425
# Retrieving altamira information for city 426
# Retrieving grand forks information for city 427
# khonuu Does Not Exist!
# Retrieving brae information for city 428
# Retrieving mount isa information for city 429
# Retrieving teguise information for city 430
# Retrieving davenda information for city 431
# Retrieving grindavik information for city 432
# Retrieving komsomolskiy information for city 433
# Retrieving marsabit information for city 434
# Retrieving vestmannaeyjar information for city 435
# Retrieving sabalgarh information for city 436
# Retrieving chicama information for city 437
# Retrieving port augusta information for city 438
# Retrieving mecca information for city 439
# Retrieving aklavik information for city 440
# Retrieving de-kastri information for city 441
# Retrieving los llanos de aridane information for city 442
# Retrieving hamilton information for city 443
# Retrieving luwuk information for city 444
# Retrieving dhidhdhoo information for city 445
# Retrieving lakshmeshwar information for city 446
# Retrieving huescar information for city 447
# Retrieving ust-kulom information for city 448
# Retrieving jacareacanga information for city 449
# Retrieving buchanan information for city 450
# Retrieving beringovskiy information for city 451
# Retrieving meadow lake information for city 452
# Retrieving imatra information for city 453
# Retrieving setubal information for city 454
# kuche Does Not Exist!
# Retrieving umred information for city 455
# Retrieving caravelas information for city 456
# Retrieving daru information for city 457
# Retrieving fallon information for city 458
# Retrieving katangli information for city 459
# Retrieving santa marta information for city 460
# Retrieving kalevala information for city 461
# Retrieving erenhot information for city 462
# Retrieving ostrovnoy information for city 463
# toliary Does Not Exist!
# Retrieving sioux lookout information for city 464
# uwayl Does Not Exist!
# Retrieving ilebo information for city 465
# Retrieving tafresh information for city 466
# Retrieving ishigaki information for city 467
# Retrieving razam information for city 468
# Retrieving rudnichnyy information for city 469
# Retrieving okhansk information for city 470
# Retrieving orlik information for city 471
# Retrieving kolondieba information for city 472
# Retrieving magadan information for city 473
# Retrieving newark information for city 474
# Retrieving wickede information for city 475
# Retrieving etne information for city 476
# Retrieving svetlogorsk information for city 477
# Retrieving balurghat information for city 478
# Retrieving chokurdakh information for city 479
# Retrieving honningsvag information for city 480
# Retrieving pimenta bueno information for city 481
# Retrieving maun information for city 482
# Retrieving yar-sale information for city 483
# Retrieving severo-yeniseyskiy information for city 484
# Retrieving bathsheba information for city 485
# Retrieving sibut information for city 486
# Retrieving odweyne information for city 487
# Retrieving hobyo information for city 488
# Retrieving beian information for city 489
# Retrieving lucapa information for city 490
# Retrieving saint pete beach information for city 491
# Retrieving aljezur information for city 492
# Retrieving payo information for city 493
# Retrieving araouane information for city 494
# Retrieving freetown information for city 495
# Retrieving murray bridge information for city 496
# Retrieving exu information for city 497
# Retrieving fangshan information for city 498
# Retrieving malinovoye ozero information for city 499
# goudomp Does Not Exist!
# Retrieving adela information for city 500
# Retrieving ust-tsilma information for city 501
# Retrieving kyra information for city 502
# Retrieving tarbagatay information for city 503
# Retrieving pushkar information for city 504
# Retrieving ambrolauri information for city 505
# Retrieving male information for city 506
# Retrieving belmonte information for city 507
# Retrieving nicoya information for city 508
# Retrieving jucurutu information for city 509
# Retrieving havre-saint-pierre information for city 510
# Retrieving dingle information for city 511
# Retrieving salinas information for city 512
# Retrieving fremont information for city 513
# Retrieving broken hill information for city 514
# Retrieving mombaca information for city 515
# Retrieving deniliquin information for city 516
# Retrieving palm coast information for city 517
# Retrieving umm lajj information for city 518
# rawannawi Does Not Exist!
# Retrieving tura information for city 519
# Retrieving whitefish information for city 520
# Retrieving svetlyy information for city 521
# Retrieving lukaya information for city 522
# Retrieving santa isabel do rio negro information for city 523
# Retrieving menongue information for city 524
# Retrieving mahebourg information for city 525
# Retrieving matamoros information for city 526
# Retrieving damara information for city 527
# Retrieving victoria point information for city 528
# Retrieving kochevo information for city 529
# Retrieving hjelset information for city 530
# Retrieving careiro da varzea information for city 531
# Retrieving vestmanna information for city 532
# Retrieving tagusao information for city 533
# Retrieving mehamn information for city 534
# Retrieving tacuarembo information for city 535
# oinoussai Does Not Exist!
# Retrieving gimbi information for city 536
# Retrieving vao information for city 537
# Retrieving dawei information for city 538
# Retrieving laguna information for city 539
# Retrieving cagliliog information for city 540
# Retrieving ningyang information for city 541
# Retrieving bemidji information for city 542
# Retrieving santa rosa information for city 543
# Retrieving guozhen information for city 544
# Retrieving sena madureira information for city 545
# Retrieving kretinga information for city 546
# Retrieving teknaf information for city 547
# Retrieving santa lucia information for city 548
# Retrieving loei information for city 549
# Retrieving batagay-alyta information for city 550
# Retrieving kambove information for city 551
# Retrieving saint-joseph information for city 552
# Retrieving matagami information for city 553
# cape elizabeth Does Not Exist!
# Retrieving iwanai information for city 554
# Retrieving catamarca information for city 555
# Retrieving hanzhong information for city 556
# Retrieving del rio information for city 557
# Retrieving noumea information for city 558
# Retrieving hede information for city 559
# Retrieving carlsbad information for city 560
# Retrieving de aar information for city 561
# sumbawa Does Not Exist!
# Retrieving richards bay information for city 562
# Retrieving corinto information for city 563
# tidore Does Not Exist!
# saleaula Does Not Exist!
# Retrieving glendive information for city 564
# Retrieving tongren information for city 565
# Retrieving englewood information for city 566
# Retrieving bukowno information for city 567
# Retrieving goundam information for city 568
# Retrieving bilma information for city 569
# Retrieving kismayo information for city 570
# Retrieving bagdarin information for city 571
# Retrieving skibbereen information for city 572
# Retrieving lekoni information for city 573
# Retrieving ust-ishim information for city 574
# Retrieving jabinyanah information for city 575
# Retrieving shemonaikha information for city 576
# Retrieving guatire information for city 577
# Retrieving biak information for city 578
# Retrieving maumere information for city 579
# Retrieving sorland information for city 580
# Retrieving medicine hat information for city 581

# %%
# Created data frame with actually cities and their properties from the empty list created above
City_df = pd.DataFrame({
    "City": citys,
    "Country": country,
    "Cloudiness": cloudiness,
    "Date": date,
    "Humidity": humidity,
    "Latitude": lat,
    "Longitude": lng,
    "Max Temperature": maxTemp,
    "Wind Speed": windSpeed
}
)
City_df.to_csv("Weather.csv", index = False, header = True)
City_df.head()
# Out:
#              City Country  Cloudiness        Date  Humidity  Latitude  \
# 0  Ribeira Grande      PT         100  1587771966        89     38.52
# 1           Airai      TL          73  1587771966        61     -8.93
# 2   Cockburn Town      TC           0  1587771966        80     21.46
# 3    San Patricio      MX          40  1587771966        83     19.22
# 4     Port Alfred      ZA          94  1587771966        93    -33.59
#
#    Longitude  Max Temperature  Wind Speed
# 0     -28.70            62.17       12.06
# 1     125.41            66.54        5.06
# 2     -71.14            79.70       20.00
# 3    -104.70            80.60        9.17
# 4      26.89            66.00        3.00

# %%
# def plotting (x, y):
#     plt.scatter(x,y)
#     plt.xlabel("Latitude")
#     plt.grid()
#     plt.ylim(0, max(y)+20)
#     return

# %%
plot_temp = City_df["Max Temperature"]
plot_humid = City_df["Humidity"]
plot_cloud = City_df["Cloudiness"]
plot_speed = City_df["Wind Speed"]
plot_lat = City_df["Latitude"]

scatter = [plot_temp, plot_humid, plot_cloud, plot_speed]
y_labels = ["Max Temperature(F)", "Humidity(%)", "Cloudiness(%)", "Wind Speed(MPH)"]

# %%
# Created for-loop to plot temperature, humidity, cloudiness and speed against latitude. 
for i in range(4):
    plt.figure()
    plt.scatter(plot_lat, scatter[i])
    plt.title(f'Latitude vs {y_labels[i]}')
    plt.grid()
    plt.xlabel("Latitude")
    plt.ylabel(f'{y_labels[i]}')
    plt.savefig(f"Images/Latitude vs {y_labels[i]}.png")
    plt.show()
    plt.tight_layout()
    
    if y_labels[i] == "Max Temperature(F)":
        print("This is a scatter plot comparing Max Temperature at different latitudes")
    elif y_labels[i] == "Humidity(%)":
        print("This is a scatter plot comparing Humidity at different latitudes")
    elif y_labels[i] == "Cloudiness(%)":
        print("This is a scatter plot comparing Cloudiness at different latitudes")
    elif y_labels[i] == "Wind Speed(MPH)":
        print("This is a scatter plot comparing Wind Speed at different latitudes")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# This is a scatter plot comparing Max Temperature at different latitudes
# <img src="data:image/png;base64,..." width="639.9999861283738">
# This is a scatter plot comparing Humidity at different latitudes
# <img src="data:image/png;base64,..." width="639.9999861283738">
# This is a scatter plot comparing Cloudiness at different latitudes
# <img src="data:image/png;base64,..." width="639.9999861283738">
# This is a scatter plot comparing Wind Speed at different latitudes

# %%
north = City_df[City_df["Latitude"] > 0]
south = City_df[City_df["Latitude"] < 0]

plot_north_lat = north["Latitude"]
plot_north_temp = north["Max Temperature"]
plot_north_humid = north["Humidity"]
plot_north_cloud = north["Cloudiness"]
plot_north_speed = north["Wind Speed"]

plot_south_lat = south["Latitude"]
plot_south_temp = south["Max Temperature"]
plot_south_humid = south["Humidity"]
plot_south_cloud = south["Cloudiness"]
plot_south_speed = south["Wind Speed"]

# %%
x_plots = [plot_north_lat, plot_south_lat, plot_north_lat, plot_south_lat, plot_north_lat, plot_south_lat, plot_north_lat, plot_south_lat]
y_plots = [plot_north_temp, plot_south_temp, plot_north_humid, plot_south_humid, plot_north_cloud, plot_south_cloud, plot_north_speed, plot_south_speed ]
x_labab = ["Northern Hemisphere Latitude", "Southern Hemisphere Latitude", "Northern Hemisphere Latitude", "Southern Hemisphere Latitude", "Northern Hemisphere Latitude", "Southern Hemisphere Latitude", "Northern Hemisphere Latitude", "Southern Hemisphere Latitude"]
y_labab = ["Max Temperature(F)", "Max Temperature(F)", "Humidity(%)", "Humidity(%)", "Cloudiness(%)", "Cloudiness(%)", "Wind Speed (MPH)", "Wind Speed (MPH)"]

# %%
# Created for-loop to plot temperature, humidity, cloudiness and speed against latitude for northern and southern hemisphere.

for i in range(8):
    plt.figure()
    plt.scatter(x_plots[i], y_plots[i])
    plt.title(f'{x_labab[i]} vs {y_labab[i]}')
    plt.grid()
    plt.xlabel(f'{x_labab[i]}')
    plt.ylabel(f'{y_labab[i]}')
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_plots[i], y_plots[i])
    regress_values = x_plots[i]*slope + intercept
    line_eq = "y =" + str(round(slope,2)) + "x +" + str(round(intercept,2))
    plt.plot(x_plots[i], regress_values, "r-")
    plt.annotate(line_eq, (min(x_plots[i]), min(y_plots[i])), fontsize = 15, color = "red")
    print(f'The r-squared is: {rvalue**2}')
    plt.savefig(f"Images/{x_labab[i]} vs {y_labab[i]}.png")
    plt.show()
    plt.tight_layout()
    
    if y_labab[i] == "Max Temperature(F)" and x_labab[i] == "Southern Hemisphere Latitude":
        print("This is a scatter plot comparing Max Temperature at different latitudes in different hemispheres")
    elif y_labab[i] == "Humidity(%)" and x_labab[i] == "Southern Hemisphere Latitude":
        print("This is a scatter plot comparing Humidity at different latitudes in different hemispheres")
    elif y_labab[i] == "Cloudiness(%)" and x_labab[i] == "Southern Hemisphere Latitude":
        print("This is a scatter plot comparing Cloudiness at different latitudes in different hemispheres")
    elif y_labab[i] == "Wind Speed (MPH)" and x_labab[i] == "Southern Hemisphere Latitude":
        print("This is a scatter plot comparing Wind Speed at different latitudes in different hemispheres")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# The r-squared is: 0.7548971916767819
# <img src="data:image/png;base64,..." width="639.9999861283738">
# The r-squared is: 0.4805540122617664
# This is a scatter plot comparing Max Temperature at different latitudes in different hemispheres
# <img src="data:image/png;base64,..." width="639.9999861283738">
# The r-squared is: 0.047771007587464366
# <img src="data:image/png;base64,..." width="639.9999861283738">
# The r-squared is: 0.012411217936116508
# This is a scatter plot comparing Humidity at different latitudes in different hemispheres
# <img src="data:image/png;base64,..." width="639.9999861283738">
# The r-squared is: 0.00995800967446105
# <img src="data:image/png;base64,..." width="639.9999861283738">
# The r-squared is: 0.003703864107280802
# This is a scatter plot comparing Cloudiness at different latitudes in different hemispheres
# <img src="data:image/png;base64,..." width="639.9999861283738">
# The r-squared is: 0.01226120896340397
# <img src="data:image/png;base64,..." width="639.9999861283738">
# The r-squared is: 0.056605554156624376
# This is a scatter plot comparing Wind Speed at different latitudes in different hemispheres
